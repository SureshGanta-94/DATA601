# %% [markdown]
# # Week 12 Homework - Generate fake data
#
# Extend the class `FakeDataGenerator` and add the following features to the extended class.
#
# * Email address
# * Phone number
# * Person's name
# * Year born. (Use realistic values.)
# * Number of kids. (Use realistic values.)
# * Marital status. (Single/Married)
# * Annual income. (Optional challenge: Use a non-uniform distribution)
#
# * have a method to write it to a file in csv format

# %%
# Use this or replace this with yours from your week10 hw. (It's up to you.)

import pandas as pd
import random
from faker import Faker

class FakeDataGenerator:
    
    def __init__(self, df = None, rows=10):
        """
        This class generates fake data
        
        If data frame is passed in it will add the fake data to it. 
        Otherwise, it will create a new data frame
        
        Parameters:
        -----------
        df: 
          DataFrame default is None
          
        rows:
          If df None, this parameter will be used to create a data frame with `row` length
        """
        # code goes under this line. 
        # I will deduct points if any code is written above the comments!
          
        self.fake = Faker()
        
        if df is not None:
            self.df = df
            self.rows = len(df)
        else:
            self.df = pd.DataFrame()
            self.rows = rows
        
        
    def add_random_number(self, column_name, small_value, high_value): # optional: add probabilities 
        """
        adds fake numbers to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [random.randint(small_value,high_value) for i in range(self.rows)]
        
        return self.df       
    
        
    def add_name(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.first_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_last_name(self, column_name):
        """
        adds fake last name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.last_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_email(self, column_name):
        """
        adds fake email to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.email() for i in range(self.rows)]
        
        return self.df
    
    
    def add_phone_number(self, column_name):
        """
        adds fake phone number to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.phone_number() for i in range(self.rows)]
        
        return self.df
    
    
    def add_address(self, column_name):
        """
        adds fake address to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.address() for i in range(self.rows)]
        
        return self.df

# %%
# complete this
class PocDataGenerator(FakeDataGenerator):
    def year_born(self,column_name):
        self.df[column_name] = [random.randint(1920,2021) for i in range(self.rows)]
        return self.df
    def marital_status(self,column_name):
        self.df[column_name] = [random.choice(['single','married']) if self.df['birth_year'].iloc[i]<=1990 else 'single' for i in range(self.rows)]
        return self.df
    def num_of_kids(self,column_name):
        self.df[column_name] = [random.randint(0,4) if self.df['birth_year'].iloc[i]<=1990 else 0 for i in range(self.rows)]
        return self.df
    def annual_income(self,column_name):
        self.df[column_name] = [random.randint(100000,1000000) for i in range(self.rows)]
        return self.df

# %%
df = pd.DataFrame()
df['product_id'] = [i + 123 for i in range(25)]
df.head()
# Out:
#    product_id
# 0         123
# 1         124
# 2         125
# 3         126
# 4         127

# %%
g = PocDataGenerator(df)

# %%
df = g.add_name('first_name')
g.add_last_name('last_name')
g.add_email('email')
g.add_address('home_address')
g.year_born('birth_year')
g.marital_status('marital_status')
g.num_of_kids('num_of_kids')
g.annual_income('annual_income')
# Out:
#     product_id  first_name    last_name                        email  \
# 0          123     Anthony  Blankenship       melissawhite@gmail.com
# 1          124       Bobby        Wells  marshalljeffrey@hotmail.com
# 2          125      Rachel        Cohen      zhangjoseph@hotmail.com
# 3          126     Heather    Hernandez        priceronald@gmail.com
# 4          127     Caitlin       Vaughn        susan59@anderson.info
# 5          128      Hannah      Holland       davidjames@barrera.biz
# 6          129  Jacqueline        Smith   edwardharrington@gmail.com
# 7          130       Debra       Holmes         lewispeter@gmail.com
# 8          131       Paula          Day             sdavis@yahoo.com
# 9          132   Alexander       Turner           joshua30@yates.com
# 10         133       David        Eaton         elliottray@yahoo.com
# 11         134     Crystal       Morton           ijohnson@yahoo.com
# 12         135     Melissa       Howell          vholland@rangel.net
# 13         136     Deborah         King          lcummings@yahoo.com
# 14         137    Jennifer       Rivera        patrick63@aguilar.biz
# 15         138       James        Mills  scottcarter@ward-vargas.biz
# 16         139      Nicole        Villa         opacheco@hotmail.com
# 17         140   Stephanie    Hernandez        brianmccoy@taylor.com
# 18         141     Jeffrey        Hicks     torresdonald@hotmail.com
# 19         142      Daniel        Braun            brian40@davis.com
# 20         143      Briana    Gallagher       melissahicks@gmail.com
# 21         144    Michelle        Patel             kent66@yahoo.com
# 22         145       Megan        Smith           austin53@mills.com
# 23         146       Emily      Edwards          rebecca54@yahoo.com
# 24         147    Benjamin    Davenport          mark47@freeman.info
#
#                                          home_address  birth_year  \
# 0           55109 Steven Garden\nPerrymouth, NY 92049        1976
# 1                        USCGC Robinson\nFPO AA 56791        1933
# 2            899 Murray Lake\nPort Troyberg, HI 91575        1959
# 3   888 Romero Camp Suite 117\nPort Samantha, WV 7...        1964
# 4           523 Richard Cliff\nSouth Bianca, NY 84038        1981
# 5   134 Hoffman Village Apt. 571\nTamaraport, DE 9...        1974
# 6   163 Marshall Prairie Apt. 105\nJohnsonchester,...        1979
# 7       2351 Sweeney Crossing\nWest Jessica, GA 68081        1927
# 8     40836 Fleming Port\nSouth Michaelport, NV 42792        1955
# 9   57104 Tiffany Port Suite 110\nChristopherfurt,...        1999
# 10  196 Robert Path Apt. 571\nLake Matthewview, IL...        1983
# 11     98126 Dustin Hills\nLake Lindsayland, NH 77172        2021
# 12  047 English Vista Suite 236\nPort Corychester,...        1987
# 13  90813 Alison Brooks Suite 129\nKarenshire, MT ...        2002
# 14                   PSC 6045, Box 7510\nAPO AA 32657        1941
# 15  8931 Wood Tunnel Suite 063\nMullinsborough, UT...        1983
# 16         09989 Gloria Bypass\nTimothyside, OR 95252        2007
# 17  4639 Robert Loop Suite 483\nNorth Carolinefort...        1957
# 18        713 Farrell Expressway\nCookburgh, HI 47047        1974
# 19          9778 Paul Crescent\nAustinville, LA 91644        2013
# 20  75925 Morales Hills Suite 018\nSouth Michael, ...        1990
# 21           477 Robert Meadow\nPort Olivia, MI 21226        2009
# 22  33172 Jessica Drives Apt. 595\nNorth Kristenbo...        1985
# 23                   PSC 5562, Box 7981\nAPO AA 79137        1965
# 24  95186 Edwards Neck Apt. 311\nClaytonbury, NJ 9...        1996
#
#    marital_status  num_of_kids  annual_income
# 0          single            3         959198
# 1          single            1         211973
# 2          single            3         416369
# 3          single            1         303864
# 4          single            2         169093
# 5          single            2         524714
# 6          single            4         243247
# 7         married            0         456933
# 8          single            2         400500
# 9          single            0         908039
# 10         single            4         650416
# 11         single            0         847156
# 12        married            4         528000
# 13         single            0         998304
# 14        married            2         303229
# 15         single            1         176591
# 16         single            0         589424
# 17        married            0         484791
# 18        married            2         964037
# 19         single            0         975373
# 20         single            3         148579
# 21         single            0         991479
# 22        married            2         502510
# 23        married            4         296757
# 24         single            0         956902

# %%
df.to_csv (r'C:\Users\ganta\Desktop\dataframe_with_df.csv', index = False, header=True)

# %%
g = PocDataGenerator()

# %%
df2 = g.add_name('first_name')
g.add_last_name('last_name')
g.add_email('email')
g.add_address('home_address')
g.year_born('birth_year')
g.marital_status('marital_status')
g.num_of_kids('num_of_kids')
g.annual_income('annual_income')
# Out:
#   first_name  last_name                        email  \
# 0     Amanda   Marshall       jeffrey59@castillo.com
# 1    Vanessa       Ross       wallerwayne@foster.org
# 2      Kevin      Smith     jeanetteclarke@gmail.com
# 3    Gilbert  Valentine        edwardbowen@stone.com
# 4      Scott     Vargas   katherinebutler@watson.biz
# 5       Adam      Mills  qnichols@buck-fernandez.com
# 6     Thomas     Brewer           debra66@morrow.net
# 7     George     Taylor         tammy05@williams.net
# 8   Kimberly     Garcia         robert03@hotmail.com
# 9     Ronnie     Rogers  wmorrison@hopkins-leach.com
#
#                                         home_address  birth_year  \
# 0        66436 Catherine Burg\nJeremyburgh, NY 64937        1973
# 1           97300 Lam Passage\nRaymondland, GA 48206        1927
# 2     93316 Torres Spur Apt. 518\nRossside, VT 59296        2008
# 3  9687 Parker Shoals Apt. 574\nMullenborough, MS...        1954
# 4         40288 Michelle Brook\nBergerfort, LA 59149        1971
# 5    5321 Hall Island Suite 933\nAnitaport, NE 71812        2006
# 6           7318 Kaitlyn Cliffs\nHuangland, WY 79793        1944
# 7       6455 Jennifer Isle\nNew Nicolestad, MI 15044        1988
# 8                   Unit 0384 Box 5385\nDPO AP 79021        1948
# 9           74327 Jill Forest\nBrewerburgh, AL 71917        2021
#
#   marital_status  num_of_kids  annual_income
# 0        married            4         394930
# 1         single            4         801624
# 2         single            0         507473
# 3        married            2         160280
# 4        married            0         669860
# 5         single            0         628116
# 6         single            1         420022
# 7        married            1         804102
# 8         single            1         132135
# 9         single            0         236420

# %%
df2.to_csv (r'C:\Users\ganta\Desktop\dataframe_without_df.csv', index = False, header=True)
